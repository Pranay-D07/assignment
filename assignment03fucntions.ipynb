# %% [markdown]
# #**THEORY QUESTIONS:**

# %% [markdown]
# #**Q1.**What is the difference between a function and a method in python?
#
# ## the terms "function" and "method" are often used interchangeably, but there is a subtle distinction between them:
# #**Function:**
#
# #1.A self-contained block of code that performs a specific task.
# #2.Can be defined independently of any class or object.
# #3.Can be called directly by its name.
# ##Example:

# %%
def my_function(x):
    return x * 2

print(my_function(5))
# Out:
# 10

# %% [markdown]
# #**Method:**
#
# #1.A function that is associated with a particular class.
# #2.Can only be called on an instance of that class.
# #3.Typically used to access or modify the attributes of the instance.
# ##Example:

# %%
class MyClass:
    def my_method(self, x):
        return x * 2

obj = MyClass()
print(obj.my_method(5))

# %% [markdown]
# #**Q2.**Explain the concept of function arguments and parameters in python.
#
# #function arguments and parameters are related concepts that deal with the inputs to a function. While they are often used interchangeably, they refer to different things depending on the context:
#
# #**Parameter:** A variable defined within a function's parentheses. It acts as a placeholder for the actual value that will be passed to the function.
# #**Argument:** A value that is passed to a function when it's called. It corresponds to a parameter in the function's definition.

# %%
def greet(name):  # 'name' is a parameter
    print("Hello, " + name + "!")

greet("Alice")  # 'Alice' is an argument

# %% [markdown]
# #**Q3.**what are the different ways to define and call a function in python?
#
# #**Defining Functions:**
#
# #1.Regular definition:

# %%
def function_name(parameter1, parameter2, ...):
    # Function body (statements to be executed)
    return value  # Optional: Returns a value

# %% [markdown]
# #2.Lambda Functions (Anonymous Functions):

# %%
lambda_function = lambda parameter1, parameter2, ...: expression

# %% [markdown]
# #3.Nested Functions:

# %%
def outer_function(outer_parameter):
    def inner_function(inner_parameter):
        # Inner function body
    # Outer function body
    inner_function(inner_parameter)

# %% [markdown]
# #**Calling Functions:**
#
# #1.Direct Call:

# %%
function_name(argument1, argument2, ...)

# %% [markdown]
# #2.Storing in a Variable:

# %%
result = function_name(argument1, argument2, ...)

# %% [markdown]
# #3.Passing as an Argument:

# %%
def higher_order_function(func, argument):
    result = func(argument)
    return result

higher_order_function(my_function, my_argument)

# %% [markdown]
# #**Q4.**what is the purpose of the `return` statement in a python function?
#
# #The `return` statement in a Python function is used to:
#
# #1.**Specify the value that the function should return to the caller.** When a function encounters a `return` statement, it immediately stops executing and sends the specified value back to the code that called the function.
# #2.**Exit the function**. Once a `return` statement is executed, the function's execution is terminated. Any code following the `return` statement will not be executed.

# %%
def add_numbers(x, y):
    result = x + y
    return result

sum = add_numbers(3, 5)
print(sum)
# Out:
# 8

# %% [markdown]
# #**Q5.**what are iterators in python and how do they differ from iterables?
#
# #**1. Iterable**
# #An iterable is any Python object capable of returning its members one at a time, allowing it to be looped over (e.g., in a `for` loop). An iterable object has a method called `__iter__()` that returns an iterator object.
#
# #Examples of iterables include lists, tuples, dictionaries, sets, strings, and any object that implements the `__iter__()` method.
# ##Example of Iterables:

# %%
my_list = [1, 2, 3]  # A list is an iterable
for item in my_list:
    print(item)

# %% [markdown]
# #**2. Iterator**
# #An iterator is an object that represents a stream of data and provides one item at a time from that stream when requested. It keeps track of where it is in the sequence, so when you ask for the "next" item, it knows which item to provide.
#
# #An iterator must implement two methods:
#
# #`__iter__()`: Returns the iterator object itself.
# #`__next__()`: Returns the next item from the sequence. If there are no more items, it raises a StopIteration exception.
# ##Example of Iterators:

# %%
my_list = [1, 2, 3]
my_iterator = iter(my_list)  # Convert iterable to an iterator

print(next(my_iterator))  # Output: 1
print(next(my_iterator))  # Output: 2
print(next(my_iterator))  # Output: 3
# Out:
# 1
# 2
# 3

# %% [markdown]
# #**Q6.**Exlain the concept of generators in python and how they are defined.
#
# #**Defining Generators:**
#
# #`yield` keyword: The `yield` keyword is used within a generator function to return a value and pause the function's execution. When the function is called again, it resumes from where it left off and continues until the next `yield` statement or the end of the function.
#
# ##**Syntax:**

# %%
def generator_function():
    # Generator body
    yield value1
    yield value2
    # ...

# %% [markdown]
# ##**Example:**

# %%
def count_up(start=0):
    while True:
        yield start
        start += 1

counter = count_up()
for i in range(5):
    print(next(counter))

# %% [markdown]
# #**Q7.**What are the advantages of using generators over regular function?
#
#
# ##**Advantages of Generators Over Regular Functions:**
#
# #**1.Memory Efficiency:** Generators produce values one at a time, avoiding the need to store the entire sequence in memory. This is especially beneficial when dealing with large datasets or infinite sequences.
# #**2.Lazy Evaluation:** Generators only produce values when requested, which can improve performance in certain scenarios, especially when calculations are expensive or time-consuming.
# #**3.Simpler Code:** Generators often lead to more concise and readable code, especially for tasks that involve producing sequences of values.
# #**4.Infinite Sequences:** Generators can be used to create infinite sequences, which are not possible with regular functions.
# #5.**Custom Iterators:** Generators provide a flexible way to create custom iterators, allowing you to define how elements are produced and accessed.

# %% [markdown]
# #**Q8**.What is a lambda function in python and when is it typically used?
#
# #**Lambda Functions in Python** also known as an anonymous function, is a small, inline function defined without a name. It's often used for short, simple functions that are only needed once.
#
# ##Example:

# %%
add = lambda x, y: x + y
result = add(3, 4)
print(result)
# Out:
# 7

# %% [markdown]
# #**Common Use Cases:**
#
# #**1.Function Arguments:** Lambda functions are often used as arguments to other functions, especially those that require a function as input. For example:

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x**2, numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #**2.Sorting Lists:** Lambda functions can be used as the `key` argument in the `sorted()` function to customize the sorting criteria:

# %%
items = [('item1', 3), ('item2', 1), ('item3', 2)]
sorted_items = sorted(items, key=lambda x: x[1])
print(sorted_items)
# Out:
# [('item2', 1), ('item3', 2), ('item1', 3)]

# %% [markdown]
# #**Q9**Explain the purpose and usage of the `map{}` function in python.
#
# #The `map()` function in Python is a built-in function that applies a given function to each item of an iterable (like a list, tuple, or dictionary) and returns an iterator containing the results.
#
# #Purpose:
#
# #To apply a function to each element of an iterable efficiently.
# #To transform elements of an iterable into a new format or value.
#
# ##Example:

# %%
numbers = [1, 2, 3, 4, 5]

# Square each number using a lambda function
squared_numbers = map(lambda x: x**2, numbers)

# Convert the iterator to a list for printing
squared_numbers_list = list(squared_numbers)
print(squared_numbers_list)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #**Q10.**What is the difference between `map()`,`reduse(),and filter()` function in python?
#
# #`map()`
#
# ##**Purpose:**Applies a given function to each element of an iterable and returns an iterator containing the results.
#
# ##Example:

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = map(lambda x: x**2, numbers)
print(list(squared_numbers))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #`reduce()`
#
# ##**Purpose:** Applies a function to an iterable, cumulatively reducing it to a single value.
#
#
# ##Example:

# %%
from functools import reduce

numbers = [1, 2, 3, 4, 5]
product = reduce(lambda x, y: x * y, numbers)
print(product)
# Out:
# 120

# %% [markdown]
# #`filter()`
#
# ##**Purpose:** Creates a new iterator containing elements from the original iterable that satisfy a given predicate function.
#
# ##Example:

# %%
numbers = [1, 2, 3, 4, 5]
even_numbers = filter(lambda x: x % 2 == 0, numbers)
print(list(even_numbers))

# %% [markdown]
# #**Q11.**Using pen & paper write the internal mechanism for sum operation using reduse function on this given list:[47,11,42,13]

# %% [markdown]
# ![WhatsApp Image 2024-10-20 at 1.11.18 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Practical Questions:**

# %% [markdown]
# #**Q1.**Write a python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_even_numbers(numbers):
  """Calculates the sum of even numbers in a given list.

  Args:
    numbers: A list of numbers.

  Returns:
    The sum of even numbers in the list.
  """

  sum_even = 0
  for num in numbers:
    if num % 2 == 0:
      sum_even += num
  return sum_even

# Example usage:
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
result = sum_even_numbers(numbers)
print(result)
# Out:
# 20

# %% [markdown]
# #**Q2.**Create a python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(string):
  """Reverses the given string.

  Args:
    string: The string to be reversed.

  Returns:
    The reversed string.
  """

  reversed_string = ""
  for char in string:
    reversed_string = char + reversed_string
  return reversed_string

# Example usage:
string = "hello world"
reversed_string = reverse_string(string)
print(reversed_string)
# Out:
# dlrow olleh

# %% [markdown]
# #**Q3.**Implement a python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
  """Squares each number in a given list.

  Args:
    numbers: A list of integers.

  Returns:
    A new list containing the squares of each number.
  """

  squared_numbers = []
  for num in numbers:
    squared_numbers.append(num ** 2)
  return squared_numbers

# Example usage:
numbers = [1, 2, 3, 4, 5]
squared_numbers = square_numbers(numbers)
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #Q4.Write a python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(number):
  """Checks if a given number is prime.

  Args:
    number: The number to check.

  Returns:
    True if the number is prime, False otherwise.
  """

  if number <= 1:
    return False
  if number <= 3:
    return True
  if number % 2 == 0 or number % 3 == 0:
    return False

  i = 5
  while i * i <= number:
    if number % i == 0 or number % (i + 2) == 0:
      return False
    i += 6

  return True

# Example usage:
for num in range(1, 201):
  if is_prime(num):
    print(num, "is prime")

# %% [markdown]
# #**Q5.**Create an iterator class in python that generates the fibonacci sequence up to a specified number of terms.

# %%
class FibonacciIterator:
  """An iterator for the Fibonacci sequence."""

  def __init__(self, n):
    """Initializes the Fibonacci iterator.

    Args:
      n: The number of terms to generate.
    """

    self.n = n
    self.a, self.b = 0, 1
    self.count = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.count >= self.n:
      raise StopIteration

    if self.count == 0:
      self.count += 1
      return self.a
    elif self.count == 1:
      self.count += 1
      return self.b

    self.count += 1
    self.a, self.b = self.b, self.a + self.b
    return self.b

# Example usage:
n = 10
fibonacci_iterator = FibonacciIterator(n)
for num in fibonacci_iterator:
  print(num)

# %% [markdown]
# #**Q6.**Write agenerator function in python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
  """Generates powers of 2 up to a given exponent.

  Args:
    exponent: The maximum exponent.

  Yields:
    Powers of 2 up to the given exponent.
  """

  power = 1
  for _ in range(exponent + 1):
    yield power
    power *= 2

# Example usage:
exponent = 5
for power in powers_of_two(exponent):
  print(power)

# %% [markdown]
# #**Q7.**Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_lines(filename):
  """Reads a file line by line and yields each line as a string.

  Args:
    filename: The name of the file to read.

  Yields:
    Each line of the file as a string.
  """

  with open(filename, 'r') as file:
    for line in file:
      yield line.strip()

# Example usage:
filename = "example.txt"
for line in read_file_lines(filename):
  print(line)

# %% [markdown]
# #**Q8.**Use a lambda function in python to sort a list of tuples based on the second element of each tuple.

# %%
tuples = [('item1', 3), ('item2', 1), ('item3', 2)]

sorted_tuples = sorted(tuples, key=lambda x: x[1])

print(sorted_tuples)
# Out:
# [('item2', 1), ('item3', 2), ('item1', 3)]

# %% [markdown]
# #**Q9.**Write a python program that uses `map()` to convert a list of temperatures from celsius to fahrenheit.

# %%
def celsius_to_fahrenheit(celsius):
  """Converts Celsius to Fahrenheit.

  Args:
    celsius: The temperature in Celsius.

  Returns:
    The temperature in Fahrenheit.
  """

  return (celsius * 9/5) + 32

temperatures_celsius = [25, 30, 35, 40]

temperatures_fahrenheit = map(celsius_to_fahrenheit, temperatures_celsius)

print(list(temperatures_fahrenheit))

# %% [markdown]
# #**Q10.**Create a python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(string):
  """Removes all vowels from a given string.

  Args:
    string: The input string.

  Returns:
    The string without vowels.
  """

  vowels = "aeiouAEIOU"
  return "".join(char for char in string if char not in vowels)

string = "Hello, world!"
filtered_string = filter(lambda char: char not in "aeiouAEIOU", string)
print("".join(filtered_string))
# Out:
# Hll, wrld!
